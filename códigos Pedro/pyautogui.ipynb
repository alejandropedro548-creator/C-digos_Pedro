# %%
import pyautogui as aut
import time

# %%
#estou importando o pyatogui e apilidando ele de aut
import pyautogui as aut
import subprocess
#pressiono a tecla de atalho
aut.hotkey('win')
#espera 1 segundo
aut.sleep(1)
#entrando no navegador
aut.write('chrome', interval=0.1)
aut.press('Enter')
aut.sleep(0.7)
#abri o google sala de aula
aut.write('https://classroom.google.com/c/NzAwNTU0Njc2MzY3')
aut.press('Enter')
aut.sleep(1)
#entrei no que o professor postou
aut.moveTo(1085,676)
aut.sleep(3)
aut.click()
#abri o que o professor postou
aut.moveTo(1580,266)
aut.sleep(3)
aut.click()
#coloquei para abaixar
aut.moveTo(949,551)
aut.sleep(3)
aut.click()
#abre o gerenciador de arquivos
subprocess.Popen('explorer')
aut.sleep(1)
#vai na área de baixados
aut.moveTo(99,368)
aut.click()
aut.sleep(3)
#seleciona o arquivo baixado e copia 
aut.moveTo(481,194)
aut.click()
aut.hotkey('ctrl', 'x')
aut.sleep(1)
#vai nos meus codigos
aut.moveTo(77,339)
aut.click()
aut.sleep(1)
aut.moveTo(589,167)
aut.click()
aut.press('Enter')
aut.sleep(1)
#cola o arquivo baixado
aut.hotkey('ctrl', 'v')
aut.sleep(1)
#abre o visual 
aut.moveTo(711,69)
aut.click()
aut.write('cmd')
aut.press('Enter')
aut.sleep(1)
aut.write('code .')
aut.press('Enter')

# %%
aut.mouseInfo()

# %%
#estou importando o pyatogui e apilidando ele de aut
import pyautogui as aut
#pressiono a tecla de atalho
aut.hotkey('win')
#espera 1 segundo
aut.sleep(1)
#entrando na calculadora
aut.write('calculadora', interval=0.1)
aut.press('Enter')
aut.sleep(0.7)
#executando o calculo 59 + 37
aut.moveTo(167,424)
aut.click()
aut.sleep(1)
aut.moveTo(247,373)
aut.click()
aut.sleep(1)
aut.moveTo(327,477)
aut.click()
aut.sleep(1)
aut.moveTo(242,475)
aut.click()
aut.sleep(1)
aut.moveTo(95,374)
aut.click()
aut.sleep(1)
aut.moveTo(313,529)
aut.click()
aut.sleep(1)
aut.moveTo(350,52)
aut.click()
aut.sleep(2)

# %%
#pressiono a tecla de atalho
aut.hotkey('win')
#espera 1 segundo
aut.sleep(1)
#entrando no paint
aut.write('paint', interval=0.1)
aut.press('Enter')
aut.sleep(0.7)
aut.moveTo(519,82)
aut.click()
# Move até o ponto inicial
aut.moveTo(651,902)
# Pressiona o botão do mouse (início do arrasto)
aut.mouseDown()
# Move até o ponto final (mantendo o botão pressionado)
aut.moveTo(1103, 473, duration=0.5)
# Solta o botão do mouse (fim do arrasto)
aut.mouseUp()
aut.moveTo(1045,464)
aut.click()
aut.sleep(1)
aut.moveTo(1127,481)
aut.mouseDown()
aut.moveTo(889, 293, duration=0.5)
aut.moveTo(654,483)
aut.mouseDown()
aut.moveTo(888, 293, duration=0.5)
aut.moveTo(715,197)
aut.click()
aut.moveTo(694,553)
aut.mouseDown()
aut.moveTo(824, 651, duration=0.5)
aut.moveTo(1084,555)
aut.moveTo(954, 648, duration=0.5)
aut.moveTo(822,773)
aut.moveTo(702, 867, duration=0.5)
aut.moveTo(645,196)
aut.sleep(1)
aut.click()
aut.moveTo(763,867)
aut.moveTo(761, 774, duration=0.5)
aut.moveTo(1256,646)
aut.moveTo(1256, 555, duration=0.5)
